# %%
import pandas as pd

# %%
df = pd.read_csv("expected_stats.csv")
df.head(10)
# Out:
#   last_name, first_name  player_id  year   pa  bip     ba  est_ba  \
# 0         Duran, Jarren     680776  2025  239  169  0.268   0.270
# 1       Carroll, Corbin     682998  2025  238  155  0.271   0.284
# 2        Devers, Rafael     646240  2025  236  140  0.299   0.303
# 3          Tucker, Kyle     663656  2025  235  172  0.276   0.306
# 4        Ohtani, Shohei     660271  2025  232  146  0.302   0.335
# 5     Lindor, Francisco     596019  2025  231  168  0.277   0.272
# 6          Bichette, Bo     666182  2025  231  176  0.284   0.308
# 7      Chourio, Jackson     694192  2025  229  171  0.250   0.246
# 8        Nootbaar, Lars     663457  2025  229  159  0.247   0.270
# 9         Harper, Bryce     547180  2025  229  154  0.271   0.288
#
#    est_ba_minus_ba_diff    slg  est_slg  est_slg_minus_slg_diff   woba  \
# 0                -0.002  0.418    0.405                   0.013  0.321
# 1                -0.013  0.579    0.612                  -0.033  0.393
# ...

# %%
df["est_ba_minus_ba_diff"].describe()
# Out:
# count    251.000000
# mean      -0.006888
# std        0.028306
# min       -0.075000
# 25%       -0.026000
# 50%       -0.006000
# 75%        0.012500
# max        0.066000
# Name: est_ba_minus_ba_diff, dtype: float64
